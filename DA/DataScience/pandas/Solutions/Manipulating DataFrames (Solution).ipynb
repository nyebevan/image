# %% [markdown]
# # Import software libraries and load the datasets

# %%
import sys
import numpy as np
import pandas as pd

# Summarize software libraries used.
print('Libraries used in this project:')
print('- Python {}'.format(sys.version))
print('- NumPy {}'.format(np.__version__))
print('- pandas {}'.format(pd.__version__))

# Load the datasets.
stores_df = pd.read_csv('../data/stores_data_reindex.csv',
                        index_col = 0)
initial_df = pd.read_csv('../data/initial_invoices.csv',
                        index_col = 0)
ratings_df = pd.read_csv('../data/ratings_more.csv',
                         index_col = 0)
print('\nLoaded datasets.')

# Format floats with comma in thousands place.
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# Libraries used in this project:
# - Python 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# - NumPy 1.22.3
# - pandas 1.4.3
#
# Loaded datasets.

# %% [markdown]
# # Append the initial invoices to `stores_df`

# %%
initial_df
# Out:
#                   Date          City CustomerType  Gender         ProductLine  \
# InvoiceID
# CAR-HBE-001   1/5/2019  Carbon Creek       Member  Female   Health and beauty
# OLI-ELE-001   3/8/2019       Olinger       Normal  Female         Electronics
# CAR-HML-001   3/3/2019  Carbon Creek       Normal    Male  Home and lifestyle
# CAR-HBE-002  1/27/2019  Carbon Creek       Member    Male   Health and beauty
# CAR-STR-001   2/8/2019  Carbon Creek       Normal    Male   Sports and travel
# ...                ...           ...          ...     ...                 ...
# CAR-ELE-005   3/8/2019  Carbon Creek       Normal    Male         Electronics
# GRC-HBE-005  3/29/2019   Greene City       Normal    Male   Health and beauty
# OLI-ELE-008   2/9/2019       Olinger       Normal  Female         Electronics
# CAR-FBV-005  3/23/2019  Carbon Creek       Normal    Male  Food and beverages
# GRC-HML-006   3/5/2019   Greene City       Normal    Male  Home and lifestyle
#
#              UnitPrice  Quantity   Tax  TotalPrice  Revenue   COGS
# InvoiceID
# CAR-HBE-001      74.69         7 26.14      548.97   522.83 500.24
# OLI-ELE-001      15.28         5  3.82       80.22    76.40  73.21
# CAR-HML-001      46.33         7 16.22      340.53   324.31 321.12
# CAR-HBE-002      58.22         8 23.29      489.05   465.76 430.98
# CAR-STR-001      86.31         7 30.21      634.38   604.17 578.90
# ...                ...       ...   ...         ...      ...    ...
# CAR-ELE-005      97.16         1  4.86      102.02    97.16  92.68
# GRC-HBE-005      87.87        10 43.94      922.64   878.70 848.40
# OLI-ELE-008      12.45         6  3.74       78.44    74.70  72.06
# CAR-FBV-005      52.75         3  7.91      166.16   158.25 152.99
# GRC-HML-006      82.70         6 24.81      521.01   496.20 477.84
#
# [96 rows x 11 columns]

# %%
print('Number of rows BEFORE append: {}.'.format(stores_df.shape[0]))
print('Number of rows to append: {}.'.format(initial_df.shape[0]))
#stores_df = stores_df.append(initial_df, sort = False)
stores_df = pd.concat([stores_df, initial_df])

print('Number of rows AFTER append: {}.'.format(stores_df.shape[0]))
# Out:
# Number of rows BEFORE append: 900.
# Number of rows to append: 96.
# Number of rows AFTER append: 996.

# %%
stores_df.tail()
# Out:
#                   Date          City CustomerType  Gender         ProductLine  \
# InvoiceID
# CAR-ELE-005   3/8/2019  Carbon Creek       Normal    Male         Electronics
# GRC-HBE-005  3/29/2019   Greene City       Normal    Male   Health and beauty
# OLI-ELE-008   2/9/2019       Olinger       Normal  Female         Electronics
# CAR-FBV-005  3/23/2019  Carbon Creek       Normal    Male  Food and beverages
# GRC-HML-006   3/5/2019   Greene City       Normal    Male  Home and lifestyle
#
#              UnitPrice  Quantity   Tax  TotalPrice  Revenue   COGS
# InvoiceID
# CAR-ELE-005      97.16      1.00  4.86      102.02    97.16  92.68
# GRC-HBE-005      87.87     10.00 43.94      922.64   878.70 848.40
# OLI-ELE-008      12.45      6.00  3.74       78.44    74.70  72.06
# CAR-FBV-005      52.75      3.00  7.91      166.16   158.25 152.99
# GRC-HML-006      82.70      6.00 24.81      521.01   496.20 477.84

# %% [markdown]
# # Merge the customer ratings into `stores_df`

# %%
ratings_df
# Out:
#              CustomerRating
# InvoiceID
# GRC-FBV-004            4.00
# OLI-STR-004            4.00
# GRC-HBE-010            4.00
# GRC-HBE-016            4.00
# GRC-ELE-019            4.00
# ...                     ...
# OLI-STR-002           10.00
# GRC-STR-005           10.00
# GRC-STR-011           10.00
# CAR-HBE-020           10.00
# GRC-ELE-041           10.00
#
# [996 rows x 1 columns]

# %%
print('Number of rows BEFORE merge: {}.'.format(stores_df.shape))

stores_df = stores_df.join(ratings_df)

print('Number of rows AFTER merge: {}.'.format(stores_df.shape))
# Out:
# Number of rows BEFORE merge: (996, 11).
# Number of rows AFTER merge: (996, 12).

# %%
stores_df.tail()
# Out:
#                   Date          City CustomerType  Gender         ProductLine  \
# InvoiceID
# CAR-ELE-005   3/8/2019  Carbon Creek       Normal    Male         Electronics
# GRC-HBE-005  3/29/2019   Greene City       Normal    Male   Health and beauty
# OLI-ELE-008   2/9/2019       Olinger       Normal  Female         Electronics
# CAR-FBV-005  3/23/2019  Carbon Creek       Normal    Male  Food and beverages
# GRC-HML-006   3/5/2019   Greene City       Normal    Male  Home and lifestyle
#
#              UnitPrice  Quantity   Tax  TotalPrice  Revenue   COGS  \
# InvoiceID
# CAR-ELE-005      97.16      1.00  4.86      102.02    97.16  92.68
# GRC-HBE-005      87.87     10.00 43.94      922.64   878.70 848.40
# OLI-ELE-008      12.45      6.00  3.74       78.44    74.70  72.06
# CAR-FBV-005      52.75      3.00  7.91      166.16   158.25 152.99
# GRC-HML-006      82.70      6.00 24.81      521.01   496.20 477.84
#
#              CustomerRating
# InvoiceID
# CAR-ELE-005            7.20
# GRC-HBE-005            5.10
# OLI-ELE-008            4.10
# CAR-FBV-005            9.30
# GRC-HML-006            7.40

# %% [markdown]
# # Sort the store data

# %%
stores_df.sort_index(axis = 0, inplace = True)
stores_df
# Out:
#                   Date          City CustomerType  Gender        ProductLine  \
# InvoiceID
# CAR-CLO-001  3/10/2019  Carbon Creek       Normal  Female           Clothing
# CAR-CLO-002  1/12/2019  Carbon Creek       Member  Female           Clothing
# CAR-CLO-003  2/10/2019  Carbon Creek       Member  Female           Clothing
# CAR-CLO-004  1/29/2019  Carbon Creek       Normal    Male           Clothing
# CAR-CLO-005   2/8/2019  Carbon Creek       Normal    Male           Clothing
# ...                ...           ...          ...     ...                ...
# OLI-STR-041   1/1/2019       Olinger       Member  Female  Sports and travel
# OLI-STR-042  1/30/2019       Olinger       Normal  Female  Sports and travel
# OLI-STR-043  3/14/2019       Olinger       Member    Male  Sports and travel
# OLI-STR-044  1/10/2019       Olinger       Normal  Female  Sports and travel
# OLI-STR-045  3/14/2019       Olinger       Member  Female  Sports and travel
#
#              UnitPrice  Quantity   Tax  TotalPrice  Revenue   COGS  \
# InvoiceID
# CAR-CLO-001      87.67      2.00  8.77      184.11   175.34 170.12
# CAR-CLO-002      20.01      9.00  9.00      189.09   180.09 174.55
# CAR-CLO-003      30.14     10.00 15.07      316.47   301.40 284.76
# CAR-CLO-004      83.24      9.00 37.46      786.62   749.16 709.60
# CAR-CLO-005      98.98     10.00 49.49    1,039.29   989.80 955.90
# ...                ...       ...   ...         ...      ...    ...
# OLI-STR-041      29.22      6.00  8.77      184.09   175.32 168.27
# OLI-STR-042      22.38      1.00  1.12       23.50    22.38  21.53
# OLI-STR-043      42.85      1.00  2.14       44.99    42.85  41.93
# OLI-STR-044      83.14      7.00 29.10      611.08   581.98 569.84
# OLI-STR-045      35.22      6.00 10.57      221.89   211.32 203.65
#
#              CustomerRating
# InvoiceID
# CAR-CLO-001            7.70
# CAR-CLO-002            5.70
# CAR-CLO-003            9.20
# CAR-CLO-004            7.40
# CAR-CLO-005            8.70
# ...                     ...
# OLI-STR-041            5.00
# OLI-STR-042            8.60
# OLI-STR-043            9.30
# OLI-STR-044            6.60
# OLI-STR-045            6.50
#
# [996 rows x 12 columns]

# %%
stores_df.sort_values(by = ['City', 'ProductLine', 'CustomerType'])
# Out:
#                   Date          City CustomerType  Gender        ProductLine  \
# InvoiceID
# CAR-CLO-002  1/12/2019  Carbon Creek       Member  Female           Clothing
# CAR-CLO-003  2/10/2019  Carbon Creek       Member  Female           Clothing
# CAR-CLO-007  1/23/2019  Carbon Creek       Member    Male           Clothing
# CAR-CLO-013  1/14/2019  Carbon Creek       Member  Female           Clothing
# CAR-CLO-014   2/2/2019  Carbon Creek       Member    Male           Clothing
# ...                ...           ...          ...     ...                ...
# OLI-STR-027   3/2/2019       Olinger       Normal  Female  Sports and travel
# OLI-STR-028  2/17/2019       Olinger       Normal  Female  Sports and travel
# OLI-STR-032  2/21/2019       Olinger       Normal  Female  Sports and travel
# OLI-STR-042  1/30/2019       Olinger       Normal  Female  Sports and travel
# OLI-STR-044  1/10/2019       Olinger       Normal  Female  Sports and travel
#
#              UnitPrice  Quantity   Tax  TotalPrice  Revenue   COGS  \
# InvoiceID
# CAR-CLO-002      20.01      9.00  9.00      189.09   180.09 174.55
# CAR-CLO-003      30.14     10.00 15.07      316.47   301.40 284.76
# CAR-CLO-007      17.94      5.00  4.49       94.19    89.70  85.88
# CAR-CLO-013      96.70      5.00 24.18      507.68   483.50 468.58
# CAR-CLO-014      43.13     10.00 21.57      452.87   431.30 419.05
# ...                ...       ...   ...         ...      ...    ...
# OLI-STR-027      73.98      7.00 25.89      543.75   517.86 495.93
# OLI-STR-028      46.66      9.00 21.00      440.94   419.94 409.27
# OLI-STR-032      98.80      2.00  9.88      207.48   197.60 187.39
# OLI-STR-042      22.38      1.00  1.12       23.50    22.38  21.53
# OLI-STR-044      83.14      7.00 29.10      611.08   581.98 569.84
#
#              CustomerRating
# InvoiceID
# CAR-CLO-002            5.70
# CAR-CLO-003            9.20
# CAR-CLO-007            6.80
# CAR-CLO-013            7.00
# CAR-CLO-014            5.50
# ...                     ...
# OLI-STR-027            4.10
# OLI-STR-028            5.30
# OLI-STR-032            7.70
# OLI-STR-042            8.60
# OLI-STR-044            6.60
#
# [996 rows x 12 columns]

# %%
stores_df.sort_values(by = ['CustomerRating'], ascending = False)
# Out:
#                   Date          City CustomerType  Gender         ProductLine  \
# InvoiceID
# GRC-STR-005   2/3/2019   Greene City       Member  Female   Sports and travel
# OLI-STR-002  2/15/2019       Olinger       Member  Female   Sports and travel
# GRC-STR-011  3/27/2019   Greene City       Normal    Male   Sports and travel
# CAR-HBE-020  2/20/2019  Carbon Creek       Normal  Female   Health and beauty
# GRC-ELE-041  2/25/2019   Greene City       Normal  Female         Electronics
# ...                ...           ...          ...     ...                 ...
# OLI-FBV-060   1/8/2019       Olinger       Member  Female  Food and beverages
# OLI-CLO-056  2/12/2019       Olinger       Member    Male            Clothing
# GRC-HBE-010  1/26/2019   Greene City       Member    Male   Health and beauty
# CAR-CLO-037   3/3/2019  Carbon Creek       Normal    Male            Clothing
# OLI-FBV-049  3/30/2019       Olinger       Member  Female  Food and beverages
#
#              UnitPrice  Quantity   Tax  TotalPrice  Revenue   COGS  \
# InvoiceID
# GRC-STR-005      55.07      9.00 24.78      520.41   495.63 469.75
# OLI-STR-002      24.74      3.00  3.71       77.93    74.22  70.11
# GRC-STR-011      93.39      6.00 28.02      588.36   560.34 538.89
# CAR-HBE-020      32.32     10.00 16.16      339.36   323.20 306.21
# GRC-ELE-041      52.79     10.00 26.40      554.30   527.90 502.63
# ...                ...       ...   ...         ...      ...    ...
# OLI-FBV-060      72.88      9.00 32.80      688.72   655.92 632.26
# OLI-CLO-056      52.35      1.00  2.62       54.97    52.35  50.99
# GRC-HBE-010      69.37      9.00 31.22      655.55   624.33 591.93
# CAR-CLO-037      46.41      1.00  2.32       48.73    46.41  44.83
# OLI-FBV-049      72.52      0.00 29.01      609.17   580.16 559.08
#
#              CustomerRating
# InvoiceID
# GRC-STR-005           10.00
# OLI-STR-002           10.00
# GRC-STR-011           10.00
# CAR-HBE-020           10.00
# GRC-ELE-041           10.00
# ...                     ...
# OLI-FBV-060            4.00
# OLI-CLO-056            4.00
# GRC-HBE-010            4.00
# CAR-CLO-037            4.00
# OLI-FBV-049            4.00
#
# [996 rows x 12 columns]

# %% [markdown]
# # Pivot the data so you can analyze it from different perspectives

# %%
stores_df.pivot_table(index = 'Gender',
                      columns = 'ProductLine',
                      values = 'Quantity').round(2)
# Out:
# ProductLine  Clothing  Electronics  Food and beverages  Health and beauty  \
# Gender
# Female           5.52         5.81                5.60               5.35
# Male             4.48         5.62                5.23               5.86
#
# ProductLine  Home and lifestyle  Sports and travel
# Gender
# Female                     6.26               5.64
# Male                       5.10               5.47

# %%
stores_df.pivot_table(index = 'ProductLine',
                      columns = 'City',
                      values = 'Revenue',
                      aggfunc = np.sum)
# Out:
# City                Carbon Creek  Greene City   Olinger
# ProductLine
# Clothing               15,406.17    15,631.73 20,092.04
# Electronics            17,328.81    16,239.47 18,065.69
# Food and beverages     16,345.81    14,490.37 22,635.10
# Health and beauty      11,972.86    18,567.26 15,793.38
# Home and lifestyle     20,626.21    16,713.49 12,711.78
# Sports and travel      18,450.19    19,036.38 15,011.36

# %% [markdown]
# # Use grouping to summarize categories of data

# %%
stores_df.groupby('City').sum()
# Out:
#               UnitPrice  Quantity      Tax  TotalPrice    Revenue       COGS  \
# City
# Carbon Creek  18,553.14  1,842.00 5,021.18  105,440.89 100,130.05  96,226.04
# Greene City   18,401.89  1,814.00 5,034.26  105,712.96 100,678.70  96,824.58
# Olinger       18,503.35  1,810.00 5,241.72  109,780.01 104,309.35 100,287.37
#
#               CustomerRating
# City
# Carbon Creek        2,383.80
# Greene City         2,257.50
# Olinger             2,304.10

# %%
stores_df.groupby('City')[['Revenue', 'COGS']].sum()
# Out:
#                 Revenue       COGS
# City
# Carbon Creek 100,130.05  96,226.04
# Greene City  100,678.70  96,824.58
# Olinger      104,309.35 100,287.37

# %%
stores_df.groupby('Gender')['CustomerRating'].mean()
# Out:
# Gender
# Female   6.96
# Male     6.97
# Name: CustomerRating, dtype: float64
